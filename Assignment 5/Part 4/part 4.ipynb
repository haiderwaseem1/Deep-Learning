# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from scipy.misc import imsave
import os
import shutil
from PIL import Image
import time
import random
import sys

from layers import *
from model import *

# %%
to_train = True
to_test = False
to_restore = False
output_path = "./output"
check_dir = "./output/checkpoints/"

temp_check = 0

max_epoch = 1
max_images = 600

h1_size = 150
h2_size = 300
z_size = 100
sample_size = 10
save_training_images = True

# %%
class CycleGAN():

    def input_setup(self, mode='train'):

        ''' 
        This function basically setup variables for taking image input.

        filenames_A/filenames_B -> takes the list of all training images
        self.image_A/self.image_B -> Input image with each values ranging from [-1,1]
        '''
        
        if mode == 'train':
            filenames_A = tf.train.match_filenames_once("./maps/trainA/*.jpg")    
            self.queue_length_A = tf.size(filenames_A)
            filenames_B = tf.train.match_filenames_once("./maps/trainB/*.jpg")    
            self.queue_length_B = tf.size(filenames_B)
        elif mode == 'test':
            filenames_A = tf.train.match_filenames_once("./maps/testA/*.jpg")    
            self.queue_length_A = tf.size(filenames_A)
            filenames_B = tf.train.match_filenames_once("./maps/testB/*.jpg")    
            self.queue_length_B = tf.size(filenames_B)
            
        
        filename_queue_A = tf.train.string_input_producer(filenames_A)
        filename_queue_B = tf.train.string_input_producer(filenames_B)

        image_reader = tf.WholeFileReader()
        _, image_file_A = image_reader.read(filename_queue_A)
        _, image_file_B = image_reader.read(filename_queue_B)

        self.image_A = tf.subtract(tf.div(tf.image.resize_images(tf.image.decode_jpeg(image_file_A),[256,256]),127.5),1)
        self.image_B = tf.subtract(tf.div(tf.image.resize_images(tf.image.decode_jpeg(image_file_B),[256,256]),127.5),1)

    

    def input_read(self, sess):


        '''
        It reads the input into from the image folder.

        self.fake_images_A/self.fake_images_B -> List of generated images used for calculation of loss function of Discriminator
        self.A_input/self.B_input -> Stores all the training images in python list
        '''

        # Loading images into the tensors
        coord = tf.train.Coordinator()
        threads = tf.train.start_queue_runners(coord=coord)

        num_files_A = sess.run(self.queue_length_A)
        num_files_B = sess.run(self.queue_length_B)

        self.fake_images_A = np.zeros((pool_size,1,img_height, img_width, img_layer))
        self.fake_images_B = np.zeros((pool_size,1,img_height, img_width, img_layer))


        self.A_input = np.zeros((max_images, batch_size, img_height, img_width, img_layer))
        self.B_input = np.zeros((max_images, batch_size, img_height, img_width, img_layer))

        for i in range(max_images): 
            image_tensor = sess.run(self.image_A)
            if(image_tensor.size == img_size*batch_size*img_layer):
                self.A_input[i] = image_tensor.reshape((batch_size,img_height, img_width, img_layer))

        for i in range(max_images):
            image_tensor = sess.run(self.image_B)
            if(image_tensor.size == img_size*batch_size*img_layer):
                self.B_input[i] = image_tensor.reshape((batch_size,img_height, img_width, img_layer))


        coord.request_stop()
        coord.join(threads)




    def model_setup(self):

        ''' This function sets up the model to train

        self.input_A/self.input_B -> Set of training images.
        self.fake_A/self.fake_B -> Generated images by corresponding generator of input_A and input_B
        self.lr -> Learning rate variable
        self.cyc_A/ self.cyc_B -> Images generated after feeding self.fake_A/self.fake_B to corresponding generator. This is use to calcualte cyclic loss
        '''

        self.input_A = tf.placeholder(tf.float32, [batch_size, img_width, img_height, img_layer], name="input_A")
        self.input_B = tf.placeholder(tf.float32, [batch_size, img_width, img_height, img_layer], name="input_B")
        
        self.fake_pool_A = tf.placeholder(tf.float32, [None, img_width, img_height, img_layer], name="fake_pool_A")
        self.fake_pool_B = tf.placeholder(tf.float32, [None, img_width, img_height, img_layer], name="fake_pool_B")

        self.global_step = tf.Variable(0, name="global_step", trainable=False)

        self.num_fake_inputs = 0

        self.lr = tf.placeholder(tf.float32, shape=[], name="lr")

        with tf.variable_scope("Model") as scope:
            self.fake_B = build_generator_resnet_9blocks(self.input_A, name="g_A")
            self.fake_A = build_generator_resnet_9blocks(self.input_B, name="g_B")
            self.rec_A = build_gen_discriminator(self.input_A, "d_A")
            self.rec_B = build_gen_discriminator(self.input_B, "d_B")

            scope.reuse_variables()

            self.fake_rec_A = build_gen_discriminator(self.fake_A, "d_A")
            self.fake_rec_B = build_gen_discriminator(self.fake_B, "d_B")
            self.cyc_A = build_generator_resnet_9blocks(self.fake_B, "g_B")
            self.cyc_B = build_generator_resnet_9blocks(self.fake_A, "g_A")

            scope.reuse_variables()

            self.fake_pool_rec_A = build_gen_discriminator(self.fake_pool_A, "d_A")
            self.fake_pool_rec_B = build_gen_discriminator(self.fake_pool_B, "d_B")

    def loss_calc(self):

        ''' In this function we are defining the variables for loss calcultions and traning model

        d_loss_A/d_loss_B -> loss for discriminator A/B
        g_loss_A/g_loss_B -> loss for generator A/B
        *_trainer -> Variaous trainer for above loss functions
        *_summ -> Summary variables for above loss functions'''

        cyc_loss = tf.reduce_mean(tf.abs(self.input_A-self.cyc_A)) + tf.reduce_mean(tf.abs(self.input_B-self.cyc_B))
        
        disc_loss_A = tf.reduce_mean(tf.squared_difference(self.fake_rec_A,1))
        disc_loss_B = tf.reduce_mean(tf.squared_difference(self.fake_rec_B,1))
        
        g_loss_A = cyc_loss*10 + disc_loss_B
        g_loss_B = cyc_loss*10 + disc_loss_A

        d_loss_A = (tf.reduce_mean(tf.square(self.fake_pool_rec_A)) + tf.reduce_mean(tf.squared_difference(self.rec_A,1)))/2.0
        d_loss_B = (tf.reduce_mean(tf.square(self.fake_pool_rec_B)) + tf.reduce_mean(tf.squared_difference(self.rec_B,1)))/2.0

        
        optimizer = tf.train.AdamOptimizer(self.lr, beta1=0.5)

        self.model_vars = tf.trainable_variables()

        d_A_vars = [var for var in self.model_vars if 'd_A' in var.name]
        g_A_vars = [var for var in self.model_vars if 'g_A' in var.name]
        d_B_vars = [var for var in self.model_vars if 'd_B' in var.name]
        g_B_vars = [var for var in self.model_vars if 'g_B' in var.name]
        
        self.d_A_trainer = optimizer.minimize(d_loss_A, var_list=d_A_vars)
        self.d_B_trainer = optimizer.minimize(d_loss_B, var_list=d_B_vars)
        self.g_A_trainer = optimizer.minimize(g_loss_A, var_list=g_A_vars)
        self.g_B_trainer = optimizer.minimize(g_loss_B, var_list=g_B_vars)

        for var in self.model_vars: print(var.name)

        #Summary variables for tensorboard

        self.g_A_loss_summ = tf.summary.scalar("g_A_loss", g_loss_A)
        self.g_B_loss_summ = tf.summary.scalar("g_B_loss", g_loss_B)
        self.d_A_loss_summ = tf.summary.scalar("d_A_loss", d_loss_A)
        self.d_B_loss_summ = tf.summary.scalar("d_B_loss", d_loss_B)

    def save_training_images(self, sess, epoch):

        if not os.path.exists("./output/imgs"):
            os.makedirs("./output/imgs")

        for i in range(0,10):
            fake_A_temp, fake_B_temp, cyc_A_temp, cyc_B_temp = sess.run([self.fake_A, self.fake_B, self.cyc_A, self.cyc_B],feed_dict={self.input_A:self.A_input[i], self.input_B:self.B_input[i]})
            imsave("./output/imgs/fakeB_"+ str(epoch) + "_" + str(i)+".jpg",((fake_A_temp[0]+1)*127.5).astype(np.uint8))
            imsave("./output/imgs/fakeA_"+ str(epoch) + "_" + str(i)+".jpg",((fake_B_temp[0]+1)*127.5).astype(np.uint8))
            imsave("./output/imgs/cycA_"+ str(epoch) + "_" + str(i)+".jpg",((cyc_A_temp[0]+1)*127.5).astype(np.uint8))
            imsave("./output/imgs/cycB_"+ str(epoch) + "_" + str(i)+".jpg",((cyc_B_temp[0]+1)*127.5).astype(np.uint8))
            imsave("./output/imgs/inputA_"+ str(epoch) + "_" + str(i)+".jpg",((self.A_input[i][0]+1)*127.5).astype(np.uint8))
            imsave("./output/imgs/inputB_"+ str(epoch) + "_" + str(i)+".jpg",((self.B_input[i][0]+1)*127.5).astype(np.uint8))

    def fake_image_pool(self, num_fakes, fake, fake_pool):
        ''' This function saves the generated image to corresponding pool of images.
        In starting. It keeps on feeling the pool till it is full and then randomly selects an
        already stored image and replace it with new one.'''

        if(num_fakes < pool_size):
            fake_pool[num_fakes] = fake
            return fake
        else :
            p = random.random()
            if p > 0.5:
                random_id = random.randint(0,pool_size-1)
                temp = fake_pool[random_id]
                fake_pool[random_id] = fake
                return temp
            else :
                return fake


    def train(self):


        ''' Training Function '''


        # Load Dataset from the dataset folder
        self.input_setup(mode='train')  

        #Build the network
        self.model_setup()

        #Loss function calculations
        self.loss_calc()
      
        # Initializing the global variables
        init = (tf.global_variables_initializer(), tf.local_variables_initializer())
        saver = tf.train.Saver()     

        with tf.Session() as sess:
            sess.run(init)

            #Read input to nd array
            self.input_read(sess)

            #Restore the model to run the model from last checkpoint
            if to_restore:
                chkpt_fname = tf.train.latest_checkpoint(check_dir)
                saver.restore(sess, chkpt_fname)

            writer = tf.summary.FileWriter("./output/2")

            if not os.path.exists(check_dir):
                os.makedirs(check_dir)

            # Training Loop
            for epoch in range(1):                
                print ("In the epoch ", epoch)
                saver.save(sess,os.path.join(check_dir,"cyclegan"),global_step=epoch)

                # Dealing with the learning rate as per the epoch number
                if(epoch < 100) :
                    curr_lr = 0.0002
                else:
                    curr_lr = 0.0002 - 0.0002*(epoch-100)/100

                if(save_training_images):
                    self.save_training_images(sess, epoch)

                # sys.exit()

                for ptr in range(0,max_images):
                    print("In the iteration ",ptr)
                    print("Starting",time.time()*1000.0)

                    # Optimizing the G_A network

                    _, fake_B_temp, summary_str = sess.run([self.g_A_trainer, self.fake_B, self.g_A_loss_summ],feed_dict={self.input_A:self.A_input[ptr], self.input_B:self.B_input[ptr], self.lr:curr_lr})
                    
                    writer.add_summary(summary_str, epoch*max_images + ptr)                    
                    fake_B_temp1 = self.fake_image_pool(self.num_fake_inputs, fake_B_temp, self.fake_images_B)
                    
                    # Optimizing the D_B network
                    _, summary_str = sess.run([self.d_B_trainer, self.d_B_loss_summ],feed_dict={self.input_A:self.A_input[ptr], self.input_B:self.B_input[ptr], self.lr:curr_lr, self.fake_pool_B:fake_B_temp1})
                    writer.add_summary(summary_str, epoch*max_images + ptr)
                    
                    
                    # Optimizing the G_B network
                    _, fake_A_temp, summary_str = sess.run([self.g_B_trainer, self.fake_A, self.g_B_loss_summ],feed_dict={self.input_A:self.A_input[ptr], self.input_B:self.B_input[ptr], self.lr:curr_lr})

                    writer.add_summary(summary_str, epoch*max_images + ptr)
                    
                    
                    fake_A_temp1 = self.fake_image_pool(self.num_fake_inputs, fake_A_temp, self.fake_images_A)

                    # Optimizing the D_A network
                    _, summary_str = sess.run([self.d_A_trainer, self.d_A_loss_summ],feed_dict={self.input_A:self.A_input[ptr], self.input_B:self.B_input[ptr], self.lr:curr_lr, self.fake_pool_A:fake_A_temp1})

                    writer.add_summary(summary_str, epoch*max_images + ptr)
                    
                    self.num_fake_inputs+=1
            
                        

                sess.run(tf.assign(self.global_step, epoch + 1))

            writer.add_graph(sess.graph)

    def test(self):


        ''' Testing Function'''

        print("Testing the results")
        tf.reset_default_graph()
        self.input_setup(mode='test')

        self.model_setup()
        saver = tf.train.Saver()
        init = (tf.global_variables_initializer(), tf.local_variables_initializer())

        with tf.Session() as sess:

            sess.run(init)

            self.input_read(sess)

            chkpt_fname = tf.train.latest_checkpoint(check_dir)
            saver.restore(sess, chkpt_fname)

            if not os.path.exists("./output/imgs/test/"):
                os.makedirs("./output/imgs/test/")            

            for i in range(0,100):
                fake_A_temp, fake_B_temp = sess.run([self.fake_A, self.fake_B],feed_dict={self.input_A:self.A_input[i], self.input_B:self.B_input[i]})
                imsave("./output/imgs/test/fakeB_"+str(i)+".jpg",((fake_A_temp[0]+1)*127.5).astype(np.uint8))
                imsave("./output/imgs/test/fakeA_"+str(i)+".jpg",((fake_B_temp[0]+1)*127.5).astype(np.uint8))
                imsave("./output/imgs/test/inputA_"+str(i)+".jpg",((self.A_input[i][0]+1)*127.5).astype(np.uint8))
                imsave("./output/imgs/test/inputB_"+str(i)+".jpg",((self.B_input[i][0]+1)*127.5).astype(np.uint8))

# %%
model = CycleGAN()
model.train()
# Out:
# WARNING:tensorflow:From <ipython-input-3-113931f15b35>:24: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /Users/haiderwaseem/anaconda2/envs/DeepLearning/lib/python3.6/site-packages/tensorflow/python/training/input.py:276: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /Users/haiderwaseem/anaconda2/envs/DeepLearning/lib/python3.6/site-packages/tensorflow/python/training/input.py:188: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /Users/haiderwaseem/anaconda2/envs/DeepLearning/lib/python3.6/site-packages/tensorflow/python/training/input.py:197: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /Users/haiderwaseem/anaconda2/envs/DeepLearning/lib/python3.6/site-packages/tensorflow/python/training/input.py:197: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From <ipython-input-3-113931f15b35>:27: WholeFileReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.map(tf.read_file)`.
# Model/d_A/c4/Conv/weights:0
# Model/d_A/c4/Conv/biases:0
# Model/d_A/c4/instance_norm/scale:0
# Model/d_A/c4/instance_norm/offset:0
# Model/d_A/c5/Conv/weights:0
# Model/d_A/c5/Conv/biases:0
# Model/d_B/c1/Conv/weights:0
# Model/d_B/c1/Conv/biases:0
# Model/d_B/c2/Conv/weights:0
# Model/d_B/c2/Conv/biases:0
# Model/d_B/c2/instance_norm/scale:0
# Model/d_B/c2/instance_norm/offset:0
# Model/d_B/c3/Conv/weights:0
# Model/d_B/c3/Conv/biases:0
# Model/d_B/c3/instance_norm/scale:0
# Model/d_B/c3/instance_norm/offset:0
# Model/d_B/c4/Conv/weights:0
# Model/d_B/c4/Conv/biases:0
# Model/d_B/c4/instance_norm/scale:0
# Model/d_B/c4/instance_norm/offset:0
# Model/d_B/c5/Conv/weights:0
# Model/d_B/c5/Conv/biases:0
# WARNING:tensorflow:From <ipython-input-3-113931f15b35>:48: start_queue_runners (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# In the epoch  0
# /Users/haiderwaseem/anaconda2/envs/DeepLearning/lib/python3.6/site-packages/ipykernel_launcher.py:168: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# /Users/haiderwaseem/anaconda2/envs/DeepLearning/lib/python3.6/site-packages/ipykernel_launcher.py:169: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# /Users/haiderwaseem/anaconda2/envs/DeepLearning/lib/python3.6/site-packages/ipykernel_launcher.py:170: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# /Users/haiderwaseem/anaconda2/envs/DeepLearning/lib/python3.6/site-packages/ipykernel_launcher.py:171: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# /Users/haiderwaseem/anaconda2/envs/DeepLearning/lib/python3.6/site-packages/ipykernel_launcher.py:172: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# /Users/haiderwaseem/anaconda2/envs/DeepLearning/lib/python3.6/site-packages/ipykernel_launcher.py:173: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# In the iteration  0
# Starting 1555076189706.056
# In the iteration  1
# Starting 1555076338214.9229
# In the iteration  2
# Starting 1555076368674.821
# In the iteration  3
# Starting 1555076395075.777
# In the iteration  4
# Starting 1555076420154.1528
# In the iteration  5
# Starting 1555076455106.498
# In the iteration  6
# Starting 1555076486882.574
# In the iteration  7
# Starting 1555076517777.314
# In the iteration  8
# Starting 1555076548785.961
# In the iteration  9
# Starting 1555076580363.172
# In the iteration  10
# Starting 1555076611301.406
# In the iteration  11
# Starting 1555076642772.0059
# In the iteration  12
# Starting 1555076675962.43
# In the iteration  13
# Starting 1555076708824.759
# In the iteration  14
# Starting 1555076740402.145
# In the iteration  15
# Starting 1555076773062.061
# In the iteration  16
# Starting 1555076804457.106
# In the iteration  17
# Starting 1555076835698.669
# In the iteration  18
# Starting 1555076867625.419
# In the iteration  19
# Starting 1555076898907.158
# In the iteration  20
# Starting 1555076929602.751
# In the iteration  21
# Starting 1555076960852.175
# In the iteration  22
# Starting 1555076992305.5518
# In the iteration  23
# Starting 1555077025646.835
# In the iteration  24
# Starting 1555077057646.4387
# In the iteration  25
# Starting 1555077089709.2212
# In the iteration  26
# Starting 1555077122123.487
# In the iteration  27
# Starting 1555077154670.6409
# In the iteration  28
# Starting 1555077187421.6052
# In the iteration  29
# Starting 1555077219637.5042
# In the iteration  30
# Starting 1555077252153.874
# In the iteration  31
# Starting 1555077285736.075
# In the iteration  32
# Starting 1555077318217.565
# In the iteration  33
# Starting 1555077349842.266
# In the iteration  34
# Starting 1555077383191.846
# In the iteration  35
# Starting 1555077417041.9463
# In the iteration  36
# Starting 1555077449830.7642
# In the iteration  37
# Starting 1555077481423.756
# In the iteration  38
# Starting 1555077513125.481
# In the iteration  39
# Starting 1555077546162.3892
# In the iteration  40
# Starting 1555077578416.703
# In the iteration  41
# Starting 1555077609619.356
# In the iteration  42
# Starting 1555077641797.417
# In the iteration  43
# Starting 1555077673580.864
# In the iteration  44
# Starting 1555077705501.6892
# In the iteration  45
# Starting 1555077737750.7341
# In the iteration  46
# Starting 1555077769930.5962
# In the iteration  47
# Starting 1555077802949.3289
# In the iteration  48
# Starting 1555077835532.254
# In the iteration  49
# Starting 1555077869289.207
# In the iteration  50
# Starting 1555077901361.212
# In the iteration  51
# Starting 1555077932497.8728
# In the iteration  52
# Starting 1555077964922.933
# In the iteration  53
# Starting 1555077996938.2332
# In the iteration  54
# Starting 1555078029668.6
# In the iteration  55
# Starting 1555078061604.1301
# In the iteration  56
# Starting 1555078094947.844
# In the iteration  57
# Starting 1555078129260.6458
# In the iteration  58
# Starting 1555078164238.122
# In the iteration  59
# Starting 1555078196363.934
# In the iteration  60
# Starting 1555078228525.135
# In the iteration  61
# Starting 1555078260512.646
# In the iteration  62
# Starting 1555078292964.739
# In the iteration  63
# Starting 1555078329292.316
# In the iteration  64
# Starting 1555078361459.903
# In the iteration  65
# Starting 1555078396228.062
# In the iteration  66
# Starting 1555078429028.579
# In the iteration  67
# Starting 1555078461604.542
# In the iteration  68
# Starting 1555078495639.512
# In the iteration  69
# Starting 1555078527321.218
# In the iteration  70
# Starting 1555078559106.527
# In the iteration  71
# Starting 1555078590955.478
# In the iteration  72
# Starting 1555078622885.47
# In the iteration  73
# Starting 1555078658476.4219
# In the iteration  74
# Starting 1555078690297.447
# In the iteration  75
# Starting 1555078723247.005
# In the iteration  76
# Starting 1555078759185.161
# In the iteration  77
# Starting 1555078792518.039
# In the iteration  78
# Starting 1555078825412.977
# In the iteration  79
# Starting 1555078857590.092
# In the iteration  80
# Starting 1555078888914.003
# In the iteration  81
# Starting 1555078919524.592
# In the iteration  82
# Starting 1555078950441.275
# In the iteration  83
# Starting 1555078981115.366
# In the iteration  84
# Starting 1555079015310.47
# In the iteration  85
# Starting 1555079046922.6438
# In the iteration  86
# Starting 1555079079795.386
# In the iteration  87
# Starting 1555079110380.32
# In the iteration  88
# Starting 1555079142144.5068
# In the iteration  89
# Starting 1555079173082.525
# In the iteration  90
# Starting 1555079205161.1882
# In the iteration  91
# Starting 1555079236490.864
# In the iteration  92
# Starting 1555079268021.6162
# In the iteration  93
# Starting 1555079299753.3708
# In the iteration  94
# Starting 1555079333549.171
# In the iteration  95
# Starting 1555079373751.8599
# In the iteration  96
# Starting 1555079405322.201
# In the iteration  97
# Starting 1555079438563.0269
# In the iteration  98
# Starting 1555079469059.238
# In the iteration  99
# Starting 1555079502331.866
# In the iteration  100
# Starting 1555079534742.5908
# In the iteration  101
# Starting 1555079566095.646
# In the iteration  102
# Starting 1555079597025.0098
# In the iteration  103
# Starting 1555079627525.46
# In the iteration  104
# Starting 1555079658666.0469
# In the iteration  105
# Starting 1555079690692.7148
# In the iteration  106
# Starting 1555079722084.995
# In the iteration  107
# Starting 1555079752697.5789
# In the iteration  108
# Starting 1555079784575.7927
# In the iteration  109
# Starting 1555079816176.601
# In the iteration  110
# Starting 1555079848029.1619
# In the iteration  111
# Starting 1555079879959.458
# In the iteration  112
# Starting 1555079910900.7039
# In the iteration  113
# Starting 1555079941846.376
# In the iteration  114
# Starting 1555079975546.018
# In the iteration  115
# Starting 1555080010368.938
# In the iteration  116
# Starting 1555080042210.004
# In the iteration  117
# Starting 1555080073547.503
# In the iteration  118
# Starting 1555080105272.705
# In the iteration  119
# Starting 1555080136954.32
# In the iteration  120
# Starting 1555080168660.396
# In the iteration  121
# Starting 1555080200446.926
# In the iteration  122
# Starting 1555080232491.8022
# In the iteration  123
# Starting 1555080264230.0789
# In the iteration  124
# Starting 1555080297865.788
# In the iteration  125
# Starting 1555080329534.346
# In the iteration  126
# Starting 1555080361285.344
# In the iteration  127
# Starting 1555080393051.9402
# In the iteration  128
# Starting 1555080425025.6902
# In the iteration  129
# Starting 1555080456580.627
# In the iteration  130
# Starting 1555080488173.543
# In the iteration  131
# Starting 1555080519376.9011
# In the iteration  132
# Starting 1555080554388.677
# In the iteration  133
# Starting 1555080585875.272
# In the iteration  134
# Starting 1555080617284.394
# In the iteration  135
# Starting 1555080649888.2239
# In the iteration  136
# Starting 1555080681546.4622
# In the iteration  137
# Starting 1555080714098.862
# In the iteration  138
# Starting 1555080747216.627
# In the iteration  139
# Starting 1555080778657.616
# In the iteration  140
# Starting 1555080810418.124
# In the iteration  141
# Starting 1555080841967.52
# In the iteration  142
# Starting 1555080873569.3892
# In the iteration  143
# Starting 1555080904929.191
# In the iteration  144
# Starting 1555080937123.5508
# In the iteration  145
# Starting 1555080968785.477
# In the iteration  146
# Starting 1555081000789.115
# In the iteration  147
# Starting 1555081034000.588
# In the iteration  148
# Starting 1555081065936.5388
# In the iteration  149
# Starting 1555081097365.213
# In the iteration  150
# Starting 1555081128899.3171
# In the iteration  151
# Starting 1555081160223.969
# In the iteration  152
# Starting 1555081192493.293
# In the iteration  153
# Starting 1555081223975.169
# In the iteration  154
# Starting 1555081255604.772
# In the iteration  155
# Starting 1555081289134.851
# In the iteration  156
# Starting 1555081321752.379
# In the iteration  157
# Starting 1555081353165.115
# In the iteration  158
# Starting 1555081384067.88
# In the iteration  159
# Starting 1555081414973.8828
# In the iteration  160
# Starting 1555081446260.612
# In the iteration  161
# Starting 1555081477290.689
# In the iteration  162
# Starting 1555081508382.072
# In the iteration  163
# Starting 1555081539808.264
# In the iteration  164
# Starting 1555081571198.798
# In the iteration  165
# Starting 1555081602601.1099
# In the iteration  166
# Starting 1555081634141.4622
# In the iteration  167
# Starting 1555081666089.142
# In the iteration  168
# Starting 1555081697018.139
# In the iteration  169
# Starting 1555081728471.872
# In the iteration  170
# Starting 1555081761616.4648
# In the iteration  171
# Starting 1555081796267.427
# In the iteration  172
# Starting 1555081825361.135
# In the iteration  173
# Starting 1555081852721.3042
# In the iteration  174
# Starting 1555081879835.202
# In the iteration  175
# Starting 1555081907353.454
# In the iteration  176
# Starting 1555081934874.0698
# In the iteration  177
# Starting 1555081969744.595
# In the iteration  178
# Starting 1555082018305.133
# In the iteration  179
# Starting 1555082067192.98
# In the iteration  180
# Starting 1555082121772.3232
# In the iteration  181
# Starting 1555082191262.2341
# In the iteration  182
# Starting 1555082263295.403
# In the iteration  183
# Starting 1555082333456.523
# In the iteration  184
# Starting 1555082405451.231
# In the iteration  185
# Starting 1555082480882.932
# In the iteration  186
# Starting 1555082553111.04
# In the iteration  187
# Starting 1555082647880.358
# In the iteration  188
# Starting 1555082901049.259
# In the iteration  189
# Starting 1555083542432.956
# In the iteration  190
# Starting 1555083645596.854
# In the iteration  191
# Starting 1555083677514.9597
# In the iteration  192
# Starting 1555083715012.807
# In the iteration  193
# Starting 1555083747741.245
# In the iteration  194
# Starting 1555083778824.949
# In the iteration  195
# Starting 1555083815040.068
# In the iteration  196
# Starting 1555083846107.1091
# In the iteration  197
# Starting 1555083880054.2852
# In the iteration  198
# Starting 1555083909729.665
# In the iteration  199
# Starting 1555083943332.4622
# In the iteration  200
# Starting 1555083999728.8489
# In the iteration  201
# Starting 1555084037523.526
# In the iteration  202
# Starting 1555084065016.6577
# In the iteration  203
# Starting 1555084093726.0598
# In the iteration  204
# Starting 1555084127928.716
# In the iteration  205
# Starting 1555084156104.625
# In the iteration  206
# Starting 1555084184377.522
# In the iteration  207
# Starting 1555084211237.3708
# In the iteration  208
# Starting 1555084239571.614
# In the iteration  209
# Starting 1555084266971.654
# In the iteration  210
# Starting 1555084295179.4849
# In the iteration  211
# Starting 1555084331060.4119
# In the iteration  212
# Starting 1555084366928.241
# In the iteration  213
# Starting 1555084396652.92
# In the iteration  214
# Starting 1555084424759.671
# In the iteration  215
# Starting 1555084457032.2703
# In the iteration  216
# Starting 1555084484148.085
# In the iteration  217
# Starting 1555084526578.295
# In the iteration  218
# Starting 1555084556238.465
# In the iteration  219
# Starting 1555084583132.137
# In the iteration  220
# Starting 1555084617299.561
# In the iteration  221
# Starting 1555084645855.126
# In the iteration  222
# Starting 1555084672682.856
# In the iteration  223
# Starting 1555084702171.844
# In the iteration  224
# Starting 1555084730830.718
# In the iteration  225
# Starting 1555084759718.9482
# In the iteration  226
# Starting 1555084792498.771
# In the iteration  227
# Starting 1555084820964.167
# In the iteration  228
# Starting 1555084848729.177
# In the iteration  229
# Starting 1555084877935.576
# In the iteration  230
# Starting 1555084908024.3352
# In the iteration  231
# Starting 1555084940799.6987
# In the iteration  232
# Starting 1555084987336.8179
# In the iteration  233
# Starting 1555085020212.907
# In the iteration  234
# Starting 1555085051710.3738
# In the iteration  235
# Starting 1555085082244.641
# In the iteration  236
# Starting 1555085113619.447
# In the iteration  237
# Starting 1555085147579.378
# In the iteration  238
# Starting 1555085178459.246
# In the iteration  239
# Starting 1555085209059.17
# In the iteration  240
# Starting 1555085239641.448
# In the iteration  241
# Starting 1555085270271.229
# In the iteration  242
# Starting 1555085301060.343
# In the iteration  243
# Starting 1555085332344.0159
# In the iteration  244
# Starting 1555085363667.5598
# In the iteration  245
# Starting 1555085394702.953
# In the iteration  246
# Starting 1555085427802.7651
# In the iteration  247
# Starting 1555085458226.814
# In the iteration  248
# Starting 1555085490655.3018
# In the iteration  249
# Starting 1555085523192.7522
# In the iteration  250
# Starting 1555085554392.79
# In the iteration  251
# Starting 1555085585888.687
# In the iteration  252
# Starting 1555085617994.673
# In the iteration  253
# Starting 1555085649873.9587
# In the iteration  254
# Starting 1555085681391.532
# In the iteration  255
# Starting 1555085716239.5361
# In the iteration  256
# Starting 1555085748816.127
# In the iteration  257
# Starting 1555085784277.911
# In the iteration  258
# Starting 1555085817773.264
# In the iteration  259
# Starting 1555085852737.299
# In the iteration  260
# Starting 1555085888694.3071
# In the iteration  261
# Starting 1555085914231.513
# In the iteration  262
# Starting 1555085945221.961
# In the iteration  263
# Starting 1555085980032.4832
# In the iteration  264
# Starting 1555086010245.574
# In the iteration  265
# Starting 1555086047885.5723
# In the iteration  266
# Starting 1555086076582.6829
# In the iteration  267
# Starting 1555086106517.115
# In the iteration  268
# Starting 1555086164800.3809
# In the iteration  269
# Starting 1555086200855.5168
# In the iteration  270
# Starting 1555086232153.155
# In the iteration  271
# Starting 1555086262406.805
# In the iteration  272
# Starting 1555086292845.829
# In the iteration  273
# Starting 1555086330241.046
# In the iteration  274
# Starting 1555086364299.259
# In the iteration  275
# Starting 1555086398261.161
# In the iteration  276
# Starting 1555086434628.896
# In the iteration  277
# Starting 1555086468176.0408
# In the iteration  278
# Starting 1555086500665.63
# In the iteration  279
# Starting 1555086534528.815
# In the iteration  280
# Starting 1555086568644.902
# In the iteration  281
# Starting 1555086604229.416
# In the iteration  282
# Starting 1555086640737.8572
# In the iteration  283
# Starting 1555086674001.321
# In the iteration  284
# Starting 1555086707867.1018
# In the iteration  285
# Starting 1555086742353.9773
# In the iteration  286
# Starting 1555086777282.634
# In the iteration  287
# Starting 1555086811430.348
# In the iteration  288
# Starting 1555086847006.697
# In the iteration  289
# Starting 1555086880819.566
# In the iteration  290
# Starting 1555086919678.1829
# In the iteration  291
# Starting 1555086953724.921
# In the iteration  292
# Starting 1555086986772.393
# In the iteration  293
# Starting 1555087019668.581
# In the iteration  294
# Starting 1555087062613.6938
# In the iteration  295
# Starting 1555087095659.914
# In the iteration  296
# Starting 1555087128977.385
# In the iteration  297
# Starting 1555087162159.468
# In the iteration  298
# Starting 1555087195225.921
# In the iteration  299
# Starting 1555087228728.9211
# In the iteration  300
# Starting 1555087263175.4902
# In the iteration  301
# Starting 1555087296514.1802
# In the iteration  302
# Starting 1555087331768.2139
# In the iteration  303
# Starting 1555087366092.838
# In the iteration  304
# Starting 1555087398811.887
# In the iteration  305
# Starting 1555087431906.7332
# In the iteration  306
# Starting 1555087465650.5
# In the iteration  307
# Starting 1555087500537.149
# In the iteration  308
# Starting 1555087535208.719
# In the iteration  309
# Starting 1555087570066.984
# In the iteration  310
# Starting 1555087604682.609
# In the iteration  311
# Starting 1555087638508.377
# In the iteration  312
# Starting 1555087672397.368
# In the iteration  313
# Starting 1555087708253.2659
# In the iteration  314
# Starting 1555087742800.5151
# In the iteration  315
# Starting 1555087777574.906
# In the iteration  316
# Starting 1555087811640.206
# In the iteration  317
# Starting 1555087846023.322
# In the iteration  318
# Starting 1555087879378.083
# In the iteration  319
# Starting 1555087913311.5679
# In the iteration  320
# Starting 1555087947091.274
# In the iteration  321
# Starting 1555087981156.967
# In the iteration  322
# Starting 1555088015782.0261
# In the iteration  323
# Starting 1555088051175.498
# In the iteration  324
# Starting 1555088084514.843
# In the iteration  325
# Starting 1555088117422.482
# In the iteration  326
# Starting 1555088151517.78
# In the iteration  327
# Starting 1555088188759.443
# In the iteration  328
# Starting 1555088223459.6128
# In the iteration  329
# Starting 1555088250955.497
# In the iteration  330
# Starting 1555088278247.6458
# In the iteration  331
# Starting 1555088306433.212
# In the iteration  332
# Starting 1555088336768.1501
# In the iteration  333
# Starting 1555088364851.8423
# In the iteration  334
# Starting 1555088392169.912
# In the iteration  335
# Starting 1555088419593.718
# In the iteration  336
# Starting 1555088446904.012
# In the iteration  337
# Starting 1555088474800.009
# In the iteration  338
# Starting 1555088503202.5442
# In the iteration  339
# Starting 1555088530546.201
# In the iteration  340
# Starting 1555088557811.6758
# In the iteration  341
# Starting 1555088585104.702
# In the iteration  342
# Starting 1555088612412.2568
# In the iteration  343
# Starting 1555088639633.173
# In the iteration  344
# Starting 1555088666648.545
# In the iteration  345
# Starting 1555088693951.05
# In the iteration  346
# Starting 1555088721518.021
# In the iteration  347
# Starting 1555088748774.03
# In the iteration  348
# Starting 1555088776440.675
# In the iteration  349
# Starting 1555088803850.719
# In the iteration  350
# Starting 1555088831586.158
# In the iteration  351
# Starting 1555088861925.589
# In the iteration  352
# Starting 1555088889303.148
# In the iteration  353
# Starting 1555088916573.87
# In the iteration  354
# Starting 1555088944105.865
# In the iteration  355
# Starting 1555088971565.58
# In the iteration  356
# Starting 1555088998735.29
# In the iteration  357
# Starting 1555089025823.654
# In the iteration  358
# Starting 1555089053348.4038
# In the iteration  359
# Starting 1555089080594.371
# In the iteration  360
# Starting 1555089107891.171
# In the iteration  361
# Starting 1555089135428.6777
# In the iteration  362
# Starting 1555089163220.0452
# In the iteration  363
# Starting 1555089190975.158
# In the iteration  364
# Starting 1555089218695.937
# In the iteration  365
# Starting 1555089247532.9722
# In the iteration  366
# Starting 1555089274772.0872
# In the iteration  367
# Starting 1555089323105.6309
# In the iteration  368
# Starting 1555089356480.0288
# In the iteration  369
# Starting 1555089387955.967
# In the iteration  370
# Starting 1555089426158.9329
# In the iteration  371
# Starting 1555089460196.6309
# In the iteration  372
# Starting 1555089487359.7961
# In the iteration  373
# Starting 1555089515291.5042
# In the iteration  374
# Starting 1555089542660.728
# In the iteration  375
# Starting 1555089569044.88
# In the iteration  376
# Starting 1555089595296.807
# In the iteration  377
# Starting 1555089626216.512
# In the iteration  378
# Starting 1555089655398.915
# In the iteration  379
# Starting 1555089683030.035
# In the iteration  380
# Starting 1555089710267.621
# In the iteration  381
# Starting 1555089740192.076
# In the iteration  382
# Starting 1555089784149.302
# In the iteration  383
# Starting 1555089821693.3088
# In the iteration  384
# Starting 1555089861496.727
# In the iteration  385
# Starting 1555089895109.604
# In the iteration  386
# Starting 1555089922715.383
# In the iteration  387
# Starting 1555089960726.6711
# In the iteration  388
# Starting 1555090010172.108
# In the iteration  389
# Starting 1555090043913.291
# In the iteration  390
# Starting 1555090075101.321
# In the iteration  391
# Starting 1555090107321.186
# In the iteration  392
# Starting 1555090144512.437
# In the iteration  393
# Starting 1555090169655.694
# In the iteration  394
# Starting 1555090198756.673
# In the iteration  395
# Starting 1555090227057.792
# In the iteration  396
# Starting 1555090253925.3782
# In the iteration  397
# Starting 1555090280928.506
# In the iteration  398
# Starting 1555090310623.908
# In the iteration  399
# Starting 1555090337857.018
# In the iteration  400
# Starting 1555090365172.8152
# In the iteration  401
# Starting 1555090391975.319
# In the iteration  402
# Starting 1555090418884.965
# In the iteration  403
# Starting 1555090445689.023
# In the iteration  404
# Starting 1555090477140.506
# In the iteration  405
# Starting 1555090511053.072
# In the iteration  406
# Starting 1555090540786.2551
# In the iteration  407
# Starting 1555090573156.7869
# In the iteration  408
# Starting 1555090609762.09
# In the iteration  409
# Starting 1555090655581.618
# In the iteration  410
# Starting 1555090691624.49
# In the iteration  411
# Starting 1555090724412.047
# In the iteration  412
# Starting 1555090757642.6958
# In the iteration  413
# Starting 1555090790884.633
# In the iteration  414
# Starting 1555090824485.42
# In the iteration  415
# Starting 1555090858340.9478
# In the iteration  416
# Starting 1555090899710.351
# In the iteration  417
# Starting 1555090933426.452
# In the iteration  418
# Starting 1555090965363.542
# In the iteration  419
# Starting 1555091011076.015
# In the iteration  420
# Starting 1555091041682.954
# In the iteration  421
# Starting 1555091096939.2341
# In the iteration  422
# Starting 1555091144622.011
# In the iteration  423
# Starting 1555091194837.8042
# In the iteration  424
# Starting 1555091226002.018
# In the iteration  425
# Starting 1555091252390.962
# In the iteration  426
# Starting 1555091278373.129
# In the iteration  427
# Starting 1555091303785.044
# In the iteration  428
# Starting 1555091328648.428
# In the iteration  429
# Starting 1555091353566.608
# In the iteration  430
# Starting 1555091378518.085
# In the iteration  431
# Starting 1555091403394.6711
# In the iteration  432
# Starting 1555091433756.7969
# In the iteration  433
# Starting 1555091465759.1118
# In the iteration  434
# Starting 1555091555506.029
# In the iteration  435
# Starting 1555091602310.813
# In the iteration  436
# Starting 1555091638079.726
# In the iteration  437
# Starting 1555091671310.577
# In the iteration  438
# Starting 1555091704337.988
# In the iteration  439
# Starting 1555091735742.343
# In the iteration  440
# Starting 1555091767324.058
# In the iteration  441
# Starting 1555091811192.338
# In the iteration  442
# Starting 1555091849328.321
# In the iteration  443
# Starting 1555091880926.9153
# In the iteration  444
# Starting 1555091910104.7458
# In the iteration  445
# Starting 1555091938559.9111
# In the iteration  446
# Starting 1555091967503.917
# In the iteration  447
# Starting 1555091995800.496
# In the iteration  448
# Starting 1555092023961.684
# In the iteration  449
# Starting 1555092051996.711
# In the iteration  450
# Starting 1555092079575.775
# In the iteration  451
# Starting 1555092107535.8027
# In the iteration  452
# Starting 1555092135141.217
# In the iteration  453
# Starting 1555092162805.254
# In the iteration  454
# Starting 1555092190959.276
# In the iteration  455
# Starting 1555092237088.073
# In the iteration  456
# Starting 1555092267645.333
# In the iteration  457
# Starting 1555092298896.162
# In the iteration  458
# Starting 1555092329847.289
# In the iteration  459
# Starting 1555092361093.423
# In the iteration  460
# Starting 1555092391410.523
# In the iteration  461
# Starting 1555092421751.955
# In the iteration  462
# Starting 1555092453488.675
# In the iteration  463
# Starting 1555092483977.044
# In the iteration  464
# Starting 1555092515669.499
# In the iteration  465
# Starting 1555092545943.735
# In the iteration  466
# Starting 1555092576032.186
# In the iteration  467
# Starting 1555092608727.947
# In the iteration  468
# Starting 1555092639588.299
# In the iteration  469
# Starting 1555092671036.719
# In the iteration  470
# Starting 1555092702080.569
# In the iteration  471
# Starting 1555092733298.105
# In the iteration  472
# Starting 1555092763931.612
# In the iteration  473
# Starting 1555092794313.569
# In the iteration  474
# Starting 1555092834126.973
# In the iteration  475
# Starting 1555092871200.064
# In the iteration  476
# Starting 1555092920041.281
# In the iteration  477
# Starting 1555092968685.384
# In the iteration  478
# Starting 1555093017550.7258
# In the iteration  479
# Starting 1555093050362.601
# In the iteration  480
# Starting 1555093074266.0571
# In the iteration  481
# Starting 1555093098738.147
# In the iteration  482
# Starting 1555093122946.9912
# In the iteration  483
# Starting 1555093146870.104
# In the iteration  484
# Starting 1555093170898.745
# In the iteration  485
# Starting 1555093198859.859
# In the iteration  486
# Starting 1555093238152.717
# In the iteration  487
# Starting 1555093280188.114
# In the iteration  488
# Starting 1555093332065.1982
# In the iteration  489
# Starting 1555093360820.2822
# In the iteration  490
# Starting 1555093391031.889
# In the iteration  491
# Starting 1555093417240.551
# In the iteration  492
# Starting 1555093441998.8252
# In the iteration  493
# Starting 1555093466690.145
# In the iteration  494
# Starting 1555093492116.4421
# In the iteration  495
# Starting 1555093517764.758
# In the iteration  496
# Starting 1555093547905.707
# In the iteration  497
# Starting 1555093581444.6877
# In the iteration  498
# Starting 1555093617450.739
# In the iteration  499
# Starting 1555093651064.76
# In the iteration  500
# Starting 1555093683327.2068
# In the iteration  501
# Starting 1555093715011.344
# In the iteration  502
# Starting 1555093746624.0342
# In the iteration  503
# Starting 1555093778702.865
# In the iteration  504
# Starting 1555093810528.599
# In the iteration  505
# Starting 1555093848626.2651
# In the iteration  506
# Starting 1555093880685.987
# In the iteration  507
# Starting 1555093914410.625
# In the iteration  508
# Starting 1555093948611.984
# In the iteration  509
# Starting 1555093983366.4639
# In the iteration  510
# Starting 1555094016463.48
# In the iteration  511
# Starting 1555094049744.171
# In the iteration  512
# Starting 1555094082712.1611
# In the iteration  513
# Starting 1555094117993.534
# In the iteration  514
# Starting 1555094156832.214
# In the iteration  515
# Starting 1555094193212.513
# In the iteration  516
# Starting 1555094228029.57
# In the iteration  517
# Starting 1555094268308.227
# In the iteration  518
# Starting 1555094302906.789
# In the iteration  519
# Starting 1555094359238.496
# In the iteration  520
# Starting 1555094408122.209
# In the iteration  521
# Starting 1555094451906.0747

# %%
model.test()
